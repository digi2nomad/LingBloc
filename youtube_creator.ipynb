# %% [markdown]
# This Notebook demonstrates how to generate a Youtube video from a thumbnail image file and a podcast audio file.

# %%
# !pip install moviepy==2.2.1
# Out:
# ...
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl.metadata (1.5 kB)
# ...
#   Using cached numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached moviepy-2.2.1-py3-none-any.whl (129 kB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-win_amd64.whl (31.2 MB)
# Using cached numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    ---------------------------------------- 0/7 [tqdm]
# ...

# %%
import creator.audio_n_images_2_video as ai2vid

# %%
ai2vid.gen_video ("clips", "clips/audio.mp4", "clips/timelapse_video.mp4")
# Out:
# MoviePy - Building video clips/timelapse_video.mp4.
# MoviePy - Writing audio in timelapse_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# MoviePy - Writing video clips/timelapse_video.mp4
# MoviePy - Done !
# MoviePy - video ready clips/timelapse_video.mp4
